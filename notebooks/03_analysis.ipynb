# %%
# notebooks/03_analysis.ipynb
from src.db_utils import init_db, insert_from_csv
from pathlib import Path

init_db(Path("../db/evals.db"))
insert_from_csv(Path("../data/scored_responses.csv"), Path("../db/evals.db"))
