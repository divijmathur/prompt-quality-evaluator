# %%
# notebooks/02_auto_evaluator.ipynb
from src.auto_evaluator import evaluate_responses
from pathlib import Path

evaluate_responses(
    input_csv=Path("../data/responses.csv"),
    output_csv=Path("../data/scored_responses.csv")
)
